# %% [markdown]
# # Setup

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Conv2D
from tensorflow import keras
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# 2022-11-20 12:05:18.325775: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Prepare the data

# %%
# model parameters
num_classes = 10
input_shape = (28, 28, 1)
# load data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

#
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(y_test.shape[0], 'test samples')

# # convert class vectors to binary class matrics
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)

# # build the model
# model = keras.Sequential([keras.Input(shape=input_shape),
#                         layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
#                         layers.MaxPooling2D(pool_size=(2,2)),
#                         layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
#                         layers.Flatten(),
#                         layers.Dropout(0.5),
#                         layers.Dense(num_classes, activation='softmax')])
# model.summary()

# # train the model
# batch_size = 128
# epochs = 15
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# a = time.time()
# model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# b = time.time()
# print(f'took {b-a} to train')
# Out:
# x_train shape: (60000, 28, 28, 1)
# y_train shape: (60000,)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # machinelearningmastery.com
# https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/

# %%
# dataset=np.loadtxt('pima-indians-diabetes.data.csv', delimiter=',')
# X = dataset[:,0:8]
# y = dataset[:,8]
# print('shapes of x and y', X.shape, y.shape)
# model = Sequential()
# model.add(Dense(12, input_shape=(8,), activation='relu'))
# model.add(Dense(8, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X, y, epochs=5, batch_size=10)
# predictions = (model.predict(X) > 0.5).astype(int)

# %% [markdown]
# # Mymodel

# %%
counter = {}
for y in y_real_value:
    if y in counter:
        counter[y] += 1
    else:
        counter[y] = 1
counter
# Out:
# {9: 150,
#  3: 150,
#  6: 150,
#  8: 150,
#  4: 150,
#  0: 150,
#  1: 150,
#  5: 150,
#  2: 150,
#  7: 150}

# %%
X = np.array(X)
X = X.reshape((-1, 28, 28))
X.shape
# Out:
# (1500, 28, 28)

# %%
training_data = pd.read_csv('./image_backend/training_data.csv')
y_real_value = []
X = []
for i, row in training_data.iterrows():
    y_real_value.append(int(row['y']))
    x_row = row['X']
    x_row = x_row.strip("[")
    x_row = x_row.strip("]")
    x_row = x_row.split(',')
    x_row = [int(x) for x in x_row]
    X.append(x_row)
binary_y = []
for y in y_real_value:
    new_y = np.zeros(10)
    new_y[y] = 1
    binary_y.append(new_y)
X = np.array(X)
binary_y = np.array(binary_y)
print('shapes of x and y', X.shape, binary_y.shape)
# Out:
# shapes of x and y (1500, 784) (1500, 10)

# %%
# model = Sequential()
# model.add(Dense(112, input_shape=(784,), activation='relu'))
# model.add(Dense(56, activation='relu'))
# model.add(Dense(28, activation='relu'))
# model.add(Dense(10, activation='softmax'))
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X, binary_y, epochs=15, batch_size=64)
# model.save('image_backend/image_model.h5')
# Out:
# Epoch 1/15
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.1080
# Epoch 2/15
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3330 - accuracy: 0.1793
# Epoch 3/15
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2531 - accuracy: 0.5933
# Epoch 4/15
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1862 - accuracy: 0.7473
# Epoch 5/15
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1329 - accuracy: 0.8367
# Epoch 6/15
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0960 - accuracy: 0.8893
# Epoch 7/15
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0699 - accuracy: 0.9240
# Epoch 8/15
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0520 - accuracy: 0.9413
# Epoch 9/15
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0389 - accuracy: 0.9580
# Epoch 10/15
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 0.9687
# Epoch 11/15
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9807
# Epoch 12/15
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0175 - accuracy: 0.9880
# Epoch 13/15
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0136 - accuracy: 0.9920
# Epoch 14/15
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0107 - accuracy: 0.9947
# Epoch 15/15
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0085 - accuracy: 0.9967

# %% [markdown]
# # Attempt 2 - This one is better

# %%
training_data = pd.read_csv('./training_data.csv')
y_real_value = []
X = []
for i, row in training_data.iterrows():
    y_real_value.append(int(row['y']))
    x_row = row['X']
    x_row = x_row.strip("[")
    x_row = x_row.strip("]")
    x_row = x_row.split(',')
    x_row = [int(x) for x in x_row]
    X.append(x_row)
X = np.array(X)
X = X.reshape((-1, 28, 28))
X = np.expand_dims(X, -1)
binary_y = []
for y in y_real_value:
    new_y = np.zeros(10)
    new_y[y] = 1
    binary_y.append(new_y)
X = np.array(X)
binary_y = np.array(binary_y)
print('shapes of x and y', X.shape, binary_y.shape)
# Out:
# shapes of x and y (1500, 28, 28, 1) (1500, 10)

# %%
# model = Sequential()
# model = keras.Sequential([keras.Input(shape=[28, 28, 1]),
#                         layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
# #                         layers.MaxPooling2D(pool_size=(2,2)),
#                         layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
#                         layers.Flatten(),
#                         layers.Dropout(0.5),
#                         layers.Dense(10, activation='softmax')])
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X, binary_y, batch_size=64, epochs=15, validation_split=0.1)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dropout (Dropout)           (None, 36864)             0
#
#  dense (Dense)               (None, 10)                368650
#
# =================================================================
# Total params: 387,466
# Trainable params: 387,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(model, 'tfjs_model_dir')

# %%
import requests

# %%
requests.get(url)
# Out:
# <Response [404]>

# %%
url = 'https://github.com/jmetzg11alpine/number_image_backend/blob/main/tfjs_model_dir/group1-shard1of1.bin?raw=true'

# %%
a = requests.get(url)
a.text
# Out:
# '"�\x07��\x0f,>�\x16\x1e��Ȟ;�J��v�\t=}��<"��=X�\x11=c��=�!��n��=�D\x18>�=��`�J#Q<�ߺ=���=4q >"������=�xǽ;��=\x11�h���0>�V�?훽*��<�;%�L�\x10��?\n�\x03�\x12�\n!��Ţ\x08>jn�\x11\t\x07>�Ѱ�e�ս\x03\r,;�\r?>\x15)X=%��=�-\x06�lJ&�\x11AJ�ZkI>�P\x0f>��=\x16i��{ŵ�nޗ<7$\x1e>���=[\x1b�=6�\x04�=.\'����=8\'�=`\x141>�2�=f\x04R=�m�=~$:��#�=�\x15�=�\x1cp��\x1e���6;��r4>xJ�;�j\x03��KἛ�,>\x0f̈�쨽<P\x00�<�\x01�f#X��ũ=�\t����V=�Q\x11�4�e���\x0c���\x13���h���\r� Ui�\x1c\x1f\x0b>\n�\x03��<�=$\x0c��\x16\x0fw=*��< 8\x0e>#d�=]ւ=�~��-���C\x01&>d7\x14�+��=�&�=w���\x0fQ6<!\x1c#>ʊ7=�笻K��=�\x10���)C�V.\x16>��V�n��=�l��\x07\x05\r>�\x16\x1c=h\x1d\x10�v�">)�<yi�=ē\x00>�6��Wp\x17�6&\t>5\x15���\x1e��<0>|_@��\x11���\x05\x1d���.>�k\x15��S==�uZ�3S���\n=\x05\x17��ԱT=�\x01�=X\x06�<���<�\x1f\x1e��YH�\x18=�=�\u0cfat\x04���Z<>�`I=y\x0fi���\x1a�f+\x15>\x01n�=��\x14>�\x02\x